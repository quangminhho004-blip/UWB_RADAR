# %% [markdown]
# # TN4 — Test cuối trên GHIJ, DS-TCN 192 kênh tầm nhìn 121
#
# ## Đây là số công bố
#
# Train trên **đủ 8 người ABCDEFKL**, chấm **một lần** trên **GHIJ** — 537 buổi
# ghi của 4 người chưa từng xuất hiện ở bất kỳ bước chọn cấu hình nào.
#
# Khác với `run_cv.py`: ở đó model chỉ thấy 6 người mỗi fold và điểm dùng để
# **chọn**. Ở đây model thấy cả 8 người và điểm dùng để **báo cáo**. Theo đúng
# `docs/PROTOCOL.md` mục 6.
#
# ## Cấu hình — đã chốt xong, không chọn gì thêm ở đây
#
# | | |
# |---|---|
# | model | `ds_tcn --channels 192 --kernel_size 5 --n_blocks 4 --dropout 0.2 --norm none --dropout_kind element` |
# | tham số | **310.873** |
# | tầm nhìn | 121 |
# | loss | `mse_pearson --alpha 0,2` |
# | điểm dev của cấu hình này | **0,776011** (TN3, 4 fold, 1 seed) |
# | cùng kiến trúc, MSE thuần | 0,764428 |
#
# `alpha 0,2` chọn từ **TN3 trên tập dev**, là mức cao nhất của chính bề
# rộng kênh này. GHIJ không tham gia vào lựa chọn đó.
#
# **Một giới hạn phải ghi khi báo cáo.** TN3 cho thấy thứ hạng giữa các alpha
# không chuyển được giữa hai bề rộng kênh — tốp 3 của c64 (0,6 · 0,5 · 0,4) và
# của c192 (0,2 · 0,3 · 0,0) không giao nhau mức nào, và biên độ dao động bên
# trong mỗi cột cùng cỡ với dao động giữa các seed. Nên `alpha 0,2` là
# **mức tốt nhất đo được trên dev**, không phải mức tối ưu đã chứng minh.
#
# Điều TN3 chứng minh được là **20/20 mức alpha đều hơn MSE thuần**, ở cả hai cấu
# hình. Đó mới là phát biểu đem vào luận văn.
#
# ## Ba seed
#
# Ba seed cho ra `seed_std` của chính con số công bố — thứ trả lời được câu hỏi
# "nhỡ ăn may thì sao". Mỗi lần chạy khoảng **40 phút**, tổng khoảng
# **2 giờ**.
#
# `run_final_test.py` **tự nén và chép sang Drive sau mỗi lần chạy**, tên tệp nén
# có cả cấu hình lẫn seed nên không đè nhau. Không cần ô lưu riêng.
#
# Dừng giữa chừng cũng được: mở lại, chạy ô khôi phục ở mục 1 rồi bấm tiếp seed
# còn thiếu. Seed đã xong sẽ in `đã có kết quả macro ... — không chạy lại.`

# %% [markdown]
# ## 1. Chuẩn bị Colab

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Tải mã nguồn.

# %%
# !rm -rf /content/UWB_RADAR
# !git clone -q --branch submission --single-branch https://github.com/quangminhho004-blip/UWB_RADAR.git /content/UWB_RADAR
# %cd /content/UWB_RADAR
# !python scripts/setup_colab.py
# Out:
# /content/UWB_RADAR
#
# thư mục làm việc : /content/UWB_RADAR
# commit đồ án     : bf1ac10
# commit MobiVital : 4319731 (đã ghim)
# GPU              : NVIDIA L4, 23034 MiB

# %% [markdown]
# Lấy `by_user/` và `windows/` từ Drive. Test cuối đọc `windows/final_train/`, cắt gộp cả 8 người theo đúng thứ tự MobiVital.

# %%
# !python scripts/restore_processed_data_on_drive.py
# Out:
# by_user   : bung /content/drive/MyDrive/mobivital/by_user.tar ...
#             12 tệp
# windows   : bung /content/drive/MyDrive/mobivital/windows.tar.gz ...
#             dev_cv 8 tệp, final_train có
#
# 2.5G	data/processed/by_user
# 503M	data/processed/windows

# %% [markdown]
# Khôi phục các seed đã chạy.
#
# **Chạy ô này mỗi khi mở lại notebook.** Nó gộp `runs/*/summary.csv` vào `runs/summary.csv` — chỗ `run_final_test.py` tra để biết seed nào đã xong.

# %%
# Khôi phục kết quả đã chạy trước khi phiên bị ngắt.
#
# Mỗi tệp nén chứa một bản runs/<thực nghiệm>/summary.csv của riêng nó. Giải
# hết vào cùng một thư mục runs/ thì tệp giải sau ĐÈ summary.csv của tệp trước.
# Mà sorted() xếp "..._a0_corr0.9..." đứng SAU "..._a0.9_corr0.9...", vì trong
# bảng mã ký tự "_" lớn hơn "." — nên bản ít dòng nhất lại là bản đè cuối cùng.
# Sửa: mỗi tệp nén giải vào một thư mục tạm riêng, gộp mọi dòng lại rồi mới ghi
# runs/summary.csv một lần. Thứ tự giải nén không còn ảnh hưởng gì nữa.
import csv, glob, os, shutil, subprocess, tempfile

MAU_ZIP = "/content/drive/MyDrive/mobivital/tn4_*c192_*.zip"

rows, seen = [], set()

def collect(summary_path):
    for r in csv.DictReader(open(summary_path)):
        key = (r.get("experiment"), r.get("run_id"))
        if key not in seen:
            seen.add(key)
            rows.append(r)

for f in sorted(glob.glob(MAU_ZIP)):
    tmp = tempfile.mkdtemp()
    subprocess.run(["unzip", "-oq", f, "-d", tmp], check=True)
    for s in glob.glob(tmp + "/*/summary.csv"):
        collect(s)
        os.remove(s)   # gộp xong thì bỏ, để bước chép dưới không đè nhau nữa
    # Checkpoint và curve.csv nằm trong thư mục riêng của từng lần chạy, tên
    # không trùng nhau, nên chép chồng lên runs/ là an toàn.
    for d in os.listdir(tmp):
        shutil.copytree(tmp + "/" + d, "runs/" + d, dirs_exist_ok=True)
    shutil.rmtree(tmp)

# Dòng đã sinh ra trong chính phiên này cũng phải giữ lại.
if os.path.exists("runs/summary.csv"):
    collect("runs/summary.csv")

if rows:
    # run_cv.py tra runs/summary.csv, còn tệp nén chỉ có runs/<thực nghiệm>/summary.csv
    cols = []
    for r in rows:
        for k in r:
            if k not in cols:
                cols.append(k)
    with open("runs/summary.csv", "w", newline="") as f:
        w = csv.DictWriter(f, fieldnames=cols, restval="")
        w.writeheader()
        w.writerows(rows)
print("khôi phục", len(rows), "dòng vào runs/summary.csv")
# Out:
# khôi phục 0 dòng vào runs/summary.csv

# %% [markdown]
# ## 2. Kiểm bản cài đặt
#
# Số tham số phải ra đúng **310.873**.

# %%
# !python scripts/check_model.py --model ds_tcn --channels 192 \
    --kernel_size 5 --n_blocks 4 --dropout 0.2 --norm none --dropout_kind element
# Out:
# Kiểm model: ds_tcn
#
# 1. Hình dạng vào ra và giá trị
#    vào (4, 200)  ->  ra (4, 25)
#    ra đúng (4, 25)                                            đạt
#    mọi giá trị hữu hạn                                        đạt
#
# 2. Gradient
#    36/36 tham số nhận được gradient
#    mọi tham số đều lan ngược tới                              đạt
#
# 3. Số tham số
#    310873
#
# 4. Lưu và nạp lại state_dict
#    nạp lại cho ra đúng đầu ra cũ                              đạt
#
# 5. Riêng TCN
#    0 lớp BatchNorm1d, WeightNorm: False
#    KHÔNG có lớp chuẩn hoá nào, đúng cấu hình đã chọn          đạt
#    cũng không có WeightNorm                                   đạt
#
# 6. Loại dropout
#    0 lớp Dropout1d (xoá cả kênh), 8 lớp Dropout (xoá từng phần tử)
#    dùng nn.Dropout, xoá từng phần tử                          đạt
#
# 7. Tầm nhìn so với cửa sổ vào
#    kernel 5, 4 khối -> tầm nhìn 121, cửa sổ vào 200
#    CHÚ Ý: chỉ thấy 121/200 mẫu gần nhất, mất 40% đầu cửa sổ
#    tầm nhìn ngắn hơn cửa sổ — có chủ ý, không phải lỗi        đạt
#
# TẤT CẢ ĐẠT — bản cài đặt dùng được.

# %% [markdown]
# ## 3. Ba seed
#
# Mỗi ô train lại từ đầu trên ABCDEFKL rồi chấm GHIJ.

# %% [markdown]
# **seed 0**

# %%
# !python scripts/run_final_test.py --experiment tn4 --model ds_tcn --channels 192 \
    --kernel_size 5 --n_blocks 4 --dropout 0.2 --norm none --dropout_kind element \
    --loss mse_pearson --alpha 0.2 --seed 0
# Out:
# thực nghiệm tn4  -> runs/tn4/
# run_id   ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0
# thiết bị NVIDIA L4
#
# 292708 cửa sổ train
# 310873 tham số
#
# epoch  0  mse 0.07382  pearson 0.5520   0.6 phút
# epoch  1  mse 0.04825  pearson 0.5856   1.1 phút
# epoch  2  mse 0.04135  pearson 0.5951   1.7 phút
# epoch  3  mse 0.03739  pearson 0.6020   2.3 phút
# epoch  4  mse 0.03577  pearson 0.6079   2.8 phút
# epoch  5  mse 0.03472  pearson 0.6121   3.4 phút
# epoch  6  mse 0.03429  pearson 0.6158   4.0 phút
# epoch  7  mse 0.03461  pearson 0.6181   4.5 phút
# epoch  8  mse 0.03416  pearson 0.6213   5.1 phút
# epoch  9  mse 0.03428  pearson 0.6228   5.6 phút
# epoch 10  mse 0.03376  pearson 0.6248   6.2 phút
# epoch 11  mse 0.03384  pearson 0.6263   6.8 phút
# epoch 12  mse 0.03352  pearson 0.6285   7.3 phút
# epoch 13  mse 0.03380  pearson 0.6294   7.9 phút
# epoch 14  mse 0.03350  pearson 0.6310   8.5 phút
# epoch 15  mse 0.03358  pearson 0.6317   9.0 phút
# epoch 16  mse 0.03318  pearson 0.6338   9.6 phút
# epoch 17  mse 0.03331  pearson 0.6347   10.1 phút
# epoch 18  mse 0.03268  pearson 0.6355   10.7 phút
# epoch 19  mse 0.03274  pearson 0.6370   11.3 phút
#
# chấm điểm G H I J...
#
# ==========================================================
#    người G   0.9174
#    người H   0.6364
#    người I   0.7317
#    người J   0.8987
#    macro    0.7960409603   <- số công bố
#    micro    0.7908559903
# ==========================================================
# runs/tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.txt
# runs/tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.csv
# runs/summary.csv
#
# runs/tn4/  ->  runs/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.zip   (1.2 MB)
#    1 dòng metric trong summary.csv
#
# Bên trong:
#         0  2026-09-08 19:21   tn4/
#         0  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/
#       153  2026-09-08 19:21   tn4/README.txt
#     34570  2026-09-08 19:21   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.csv
#     21072  2026-09-08 19:21   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.txt
#       555  2026-09-08 19:21   tn4/summary.csv
#      1446  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/curve.csv
#   1256035  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/final.pth
# ---------                     -------
#   1313831                     8 files
#
#
# đã chép sang /content/drive/MyDrive/mobivital/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.zip
#
# Giải nén lại đúng chỗ cũ:  unzip tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.zip -d runs/

# %% [markdown]
# **seed 1**

# %%
# !python scripts/run_final_test.py --experiment tn4 --model ds_tcn --channels 192 \
    --kernel_size 5 --n_blocks 4 --dropout 0.2 --norm none --dropout_kind element \
    --loss mse_pearson --alpha 0.2 --seed 1
# Out:
# thực nghiệm tn4  -> runs/tn4/
# run_id   ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1
# thiết bị NVIDIA L4
#
# 292708 cửa sổ train
# 310873 tham số
#
# epoch  0  mse 0.07517  pearson 0.5500   0.6 phút
# epoch  1  mse 0.04781  pearson 0.5817   1.1 phút
# epoch  2  mse 0.04207  pearson 0.5916   1.7 phút
# epoch  3  mse 0.03813  pearson 0.6010   2.2 phút
# epoch  4  mse 0.03584  pearson 0.6086   2.8 phút
# epoch  5  mse 0.03516  pearson 0.6139   3.3 phút
# epoch  6  mse 0.03520  pearson 0.6172   3.9 phút
# epoch  7  mse 0.03517  pearson 0.6203   4.4 phút
# epoch  8  mse 0.03423  pearson 0.6232   5.0 phút
# epoch  9  mse 0.03423  pearson 0.6253   5.5 phút
# epoch 10  mse 0.03361  pearson 0.6270   6.1 phút
# epoch 11  mse 0.03370  pearson 0.6285   6.7 phút
# epoch 12  mse 0.03367  pearson 0.6299   7.2 phút
# epoch 13  mse 0.03299  pearson 0.6314   7.8 phút
# epoch 14  mse 0.03304  pearson 0.6329   8.3 phút
# epoch 15  mse 0.03306  pearson 0.6340   8.9 phút
# epoch 16  mse 0.03274  pearson 0.6355   9.4 phút
# epoch 17  mse 0.03271  pearson 0.6366   10.0 phút
# epoch 18  mse 0.03267  pearson 0.6375   10.5 phút
# epoch 19  mse 0.03205  pearson 0.6384   11.1 phút
#
# chấm điểm G H I J...
#
# ==========================================================
#    người G   0.9132
#    người H   0.6596
#    người I   0.7165
#    người J   0.8833
#    macro    0.7931539468   <- số công bố
#    micro    0.7882392464
# ==========================================================
# runs/tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.txt
# runs/tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.csv
# runs/summary.csv
#
# runs/tn4/  ->  runs/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.zip   (2.3 MB)
#    2 dòng metric trong summary.csv
#
# Bên trong:
#         0  2026-09-08 19:43   tn4/
#         0  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/
#         0  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/
#       153  2026-09-08 19:43   tn4/README.txt
#     34570  2026-09-08 19:21   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.csv
#     21072  2026-09-08 19:21   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.txt
#     34533  2026-09-08 19:43   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.csv
#     21055  2026-09-08 19:43   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.txt
#       832  2026-09-08 19:43   tn4/summary.csv
#      1446  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/curve.csv
#   1256035  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/final.pth
#      1447  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/curve.csv
#   1256035  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/final.pth
# ---------                     -------
#   2627178                     13 files
#
#
# đã chép sang /content/drive/MyDrive/mobivital/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.zip
#
# Giải nén lại đúng chỗ cũ:  unzip tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.zip -d runs/

# %% [markdown]
# **seed 2**

# %%
# !python scripts/run_final_test.py --experiment tn4 --model ds_tcn --channels 192 \
    --kernel_size 5 --n_blocks 4 --dropout 0.2 --norm none --dropout_kind element \
    --loss mse_pearson --alpha 0.2 --seed 2
# Out:
# thực nghiệm tn4  -> runs/tn4/
# run_id   ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2
# thiết bị NVIDIA L4
#
# 292708 cửa sổ train
# 310873 tham số
#
# epoch  0  mse 0.07165  pearson 0.5507   0.6 phút
# epoch  1  mse 0.04793  pearson 0.5860   1.1 phút
# epoch  2  mse 0.04067  pearson 0.5972   1.7 phút
# epoch  3  mse 0.03709  pearson 0.6060   2.2 phút
# epoch  4  mse 0.03578  pearson 0.6112   2.8 phút
# epoch  5  mse 0.03539  pearson 0.6153   3.3 phút
# epoch  6  mse 0.03454  pearson 0.6185   3.9 phút
# epoch  7  mse 0.03447  pearson 0.6212   4.4 phút
# epoch  8  mse 0.03392  pearson 0.6238   5.0 phút
# epoch  9  mse 0.03362  pearson 0.6261   5.5 phút
# epoch 10  mse 0.03348  pearson 0.6278   6.1 phút
# epoch 11  mse 0.03313  pearson 0.6290   6.6 phút
# epoch 12  mse 0.03318  pearson 0.6305   7.2 phút
# epoch 13  mse 0.03297  pearson 0.6316   7.7 phút
# epoch 14  mse 0.03312  pearson 0.6331   8.3 phút
# epoch 15  mse 0.03261  pearson 0.6344   8.8 phút
# epoch 16  mse 0.03248  pearson 0.6352   9.4 phút
# epoch 17  mse 0.03209  pearson 0.6367   9.9 phút
# epoch 18  mse 0.03217  pearson 0.6373   10.5 phút
# epoch 19  mse 0.03192  pearson 0.6382   11.0 phút
#
# chấm điểm G H I J...
#
# ==========================================================
#    người G   0.9113
#    người H   0.6973
#    người I   0.7446
#    người J   0.8986
#    macro    0.8129693533   <- số công bố
#    micro    0.8084747178
# ==========================================================
# runs/tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.txt
# runs/tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.csv
# runs/summary.csv
#
# runs/tn4/  ->  runs/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.zip   (3.5 MB)
#    3 dòng metric trong summary.csv
#
# Bên trong:
#         0  2026-09-08 20:05   tn4/
#         0  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/
#         0  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/
#         0  2026-09-08 19:54   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2/
#     21069  2026-09-08 20:05   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.txt
#       153  2026-09-08 20:05   tn4/README.txt
#     34570  2026-09-08 19:21   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.csv
#     21072  2026-09-08 19:21   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0.txt
#     34525  2026-09-08 20:05   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.csv
#     34533  2026-09-08 19:43   tn4/scores_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.csv
#     21055  2026-09-08 19:43   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1.txt
#      1107  2026-09-08 20:05   tn4/summary.csv
#      1446  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/curve.csv
#   1256035  2026-09-08 19:11   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed0/final.pth
#      1444  2026-09-08 19:54   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2/curve.csv
#   1256035  2026-09-08 19:54   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2/final.pth
#      1447  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/curve.csv
#   1256035  2026-09-08 19:32   tn4/ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed1/final.pth
# ---------                     -------
#   3940526                     18 files
#
#
# đã chép sang /content/drive/MyDrive/mobivital/tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.zip
#
# Giải nén lại đúng chỗ cũ:  unzip tn4_ds_tcn_c192_k5_n4_none_do0.2_dpel_mse_pearson_a0.2_corr0.9_seed2.zip -d runs/

# %% [markdown]
# ## 4. Kết quả
#
# `score_macro` là **Pearson macro theo người** trên GHIJ — trung bình từng người, rồi trung bình bốn người.

# %%
import csv, os
import statistics as st

# run_final_test.py ghi mỗi lần chạy MỘT dòng, không có dòng TONG như run_cv.py.
rows = []
if os.path.exists("runs/tn4/summary.csv"):
    rows = [r for r in csv.DictReader(open("runs/tn4/summary.csv"))
            if "_c192_" in r["run_id"]]

diem = {}
for r in rows:
    diem[int(r["seed"])] = float(r["score_macro"])

for s in sorted(diem):
    print("  seed", s, " ", round(diem[s], 6))
if len(diem) >= 2:
    v = list(diem.values())
    print("  " + "-" * 34)
    print("  trung bình", round(st.mean(v), 6))
    print("  seed_std  ", round(st.stdev(v), 6))
print()
print("  MỐC ĐỐI CHIẾU trên GHIJ")
for ten, d in (("MobiVital công bố", "0,819"),
               ("LSTM-352, 1.502.713 tham số", "0,810302"),
               ("LSTM-67", "0,801683"),
               ("DS-TCN-64 bản đầu", "0,795783")):
    print("   ", ten.ljust(30), d)
# Out:
#   seed 0   0.796041
#   seed 1   0.793154
#   seed 2   0.812969
#   ----------------------------------
#   trung bình 0.800721
#   seed_std   0.010705
#
#   MỐC ĐỐI CHIẾU trên GHIJ
#     MobiVital công bố              0,819
#     LSTM-352, 1.502.713 tham số    0,810302
#     LSTM-67                        0,801683
#     DS-TCN-64 bản đầu              0,795783

# %% [markdown]
# ## 5. Ngắt phiên

# %%
from google.colab import runtime
runtime.unassign()
